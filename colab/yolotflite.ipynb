# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install tensorflow==2.3.0

# %%
# %cd /content
# !git clone https://github.com/hunglc007/tensorflow-yolov4-tflite.git
# %cd /content/tensorflow-yolov4-tflite
# Out:
# /content
# fatal: destination path 'tensorflow-yolov4-tflite' already exists and is not an empty directory.
# /content/tensorflow-yolov4-tflite

# %%
# !cp /content/drive/MyDrive/IA3/Face_detection/cfg/obj.names /content/tensorflow-yolov4-tflite/data/classes/
# !ls /content/tensorflow-yolov4-tflite/data/classes/
# Out:
# coco.names  obj.names  voc.names  yymnist.names

# %%
# !sed -i "s/coco.names/obj.names/g" /content/tensorflow-yolov4-tflite/core/config.py

# %%
# %cd /content/tensorflow-yolov4-tflite
# Regular TensorFlow SavedModel
# !python save_model.py \
  --weights /content/drive/MyDrive/IA3/Face_detection/cfg/pesos2/yolov4-tiny_final.weights \
  --output ./checkpoints/yolov4-tiny-416 \
  --input_size 416 \
  --model yolov4 \
  --tiny \

# SavedModel to convert to TFLite
# !python save_model.py \
  --weights /content/drive/MyDrive/IA3/Face_detection/cfg/pesos2/yolov4-tiny_final.weights \
  --output ./checkpoints/yolov4-tiny-pretflite-416 \
  --input_size 416 \
  --model yolov4 \
  --tiny \
  --framework tflite
# Out:
# /content/tensorflow-yolov4-tflite
# 2021-06-20 02:37:29.646161: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-20 02:37:31.411875: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-20 02:37:31.471723: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-20 02:37:31.472326: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-20 02:37:31.472373: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd /content/tensorflow-yolov4-tflite
# !python convert_tflite.py --weights ./checkpoints/yolov4-tiny-pretflite-416 --output ./checkpoints/yolov4-tiny-416.tflite
# Out:
# /content/tensorflow-yolov4-tflite
# 2021-06-20 02:39:03.612579: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-20 02:39:04.737608: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-20 02:39:04.764787: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-20 02:39:04.765376: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-20 02:39:04.765416: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# !ls /content/drive/MyDrive/IA3/pruebas
# Out:
# 82981-CARA.jpg	    ojos-cerrados.jpg			  somnoliento1.jpg
# ojos-cerrados2.jpg  radu-florin-JyVcAIUAcPM-unsplash.jpg

# %%
# Verify
# %cd /content/tensorflow-yolov4-tflite
# !python detect.py --weights ./checkpoints/yolov4-tiny-416 --size 416 --model yolov4 \
  --image /content/drive/MyDrive/IA3/pruebas/radu-florin-JyVcAIUAcPM-unsplash.jpg \
  # --framework tflite
# Out:
# /content/tensorflow-yolov4-tflite
# 2021-06-20 02:46:27.867141: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# 2021-06-20 02:46:29.023031: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcuda.so.1
# 2021-06-20 02:46:29.051743: I tensorflow/stream_executor/cuda/cuda_gpu_executor.cc:982] successful NUMA node read from SysFS had negative value (-1), but there must be at least one NUMA node, so returning NUMA node zero
# 2021-06-20 02:46:29.052322: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1716] Found device 0 with properties:
# pciBusID: 0000:00:04.0 name: Tesla T4 computeCapability: 7.5
# coreClock: 1.59GHz coreCount: 40 deviceMemorySize: 14.75GiB deviceMemoryBandwidth: 298.08GiB/s
# 2021-06-20 02:46:29.052372: I tensorflow/stream_executor/platform/default/dso_loader.cc:48] Successfully opened dynamic library libcudart.so.10.1
# ...

# %%
# %cd /content/tensorflow-yolov4-tflite/
# !ls
from IPython.display import Image
Image('/content/tensorflow-yolov4-tflite/result.png')

# %%
# %cd /content/tensorflow-yolov4-tflite/
# !ls
from IPython.display import Image
Image('/content/tensorflow-yolov4-tflite/result.png')
